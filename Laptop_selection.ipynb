# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('laptops.csv', index_col=0)
df.head()
# Out:
#                                             img_link  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...
# 1  https://rukminim1.flixcart.com/image/312/312/x...
# 2  https://rukminim1.flixcart.com/image/312/312/l...
# 3  https://rukminim1.flixcart.com/image/312/312/x...
# 4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 2  Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 3  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
# 4      AMD Athlon Dual Core Processor   4 GB DDR4 RAM
#
#                                    os              storage  display(in inch)  \
# 0         Windows 11 Operating System           512 GB SSD              15.6
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD              15.6
# 2         Windows 11 Operating System           512 GB SSD              15.6
# 3  64 bit Windows 11 Operating System           512 GB SSD              15.6
# 4                DOS Operating System           256 GB SSD              14.0
#
#    rating  no_of_ratings  no_of_reviews
# 0     4.5           14.0            1.0
# 1     4.4           53.0            3.0
# 2     4.4         4733.0          463.0
# 3     4.3        10406.0         1040.0
# 4     3.8           18.0            3.0

# %%
data = df.copy()

# %%
df.describe()
# Out:
#        price(in Rs.)  display(in inch)      rating  no_of_ratings  \
# count     984.000000        984.000000  688.000000     688.000000
# mean    80960.720528         15.148374    4.284884     718.091570
# std     57421.220919          1.332078    0.330239    1750.817825
# min     15990.000000         11.600000    1.600000       1.000000
# 25%     42655.000000         14.000000    4.100000      14.000000
# 50%     62990.000000         15.600000    4.300000      90.000000
# 75%     94990.000000         15.600000    4.500000     453.000000
# max    419990.000000         35.000000    5.000000   15492.000000
#
#        no_of_reviews
# count     688.000000
# mean       83.898256
# std       211.596726
# min         0.000000
# 25%         2.000000
# 50%        11.000000
# 75%        53.500000
# max      2054.000000

# %%
df.describe(include=object)
# Out:
#                                                  img_link  \
# count                                                 984
# unique                                                584
# top     https://rukminim1.flixcart.com/image/312/312/x...
# freq                                                   41
#
#                                  name                           processor  \
# count                             984                                 984
# unique                            506                                  59
# top     Lenovo Intel Core i5 11th Gen  Intel Core i3 Processor (11th Gen)
# freq                               43                                 131
#
#                   ram                                  os     storage
# count             984                                 984         984
# unique             22                                  11          16
# top     8 GB DDR4 RAM  64 bit Windows 11 Operating System  512 GB SSD
# freq              463                                 527         575

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   img_link          984 non-null    object
#  1   name              984 non-null    object
#  2   price(in Rs.)     984 non-null    int64
#  3   processor         984 non-null    object
#  4   ram               984 non-null    object
#  5   os                984 non-null    object
#  6   storage           984 non-null    object
#  7   display(in inch)  984 non-null    float64
#  8   rating            688 non-null    float64
#  9   no_of_ratings     688 non-null    float64
#  10  no_of_reviews     688 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 92.2+ KB

# %%
df.isna().sum()
# Out:
# img_link              0
# name                  0
# price(in Rs.)         0
# processor             0
# ram                   0
# os                    0
# storage               0
# display(in inch)      0
# rating              296
# no_of_ratings       296
# no_of_reviews       296
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   img_link          984 non-null    object
#  1   name              984 non-null    object
#  2   price(in Rs.)     984 non-null    int64
#  3   processor         984 non-null    object
#  4   ram               984 non-null    object
#  5   os                984 non-null    object
#  6   storage           984 non-null    object
#  7   display(in inch)  984 non-null    float64
#  8   rating            984 non-null    float64
#  9   no_of_ratings     984 non-null    float64
#  10  no_of_reviews     984 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 92.2+ KB

# %%
df.rename(columns={'price(in Rs.)':'price', 'display(in inch)': 'display'}, inplace=True)

# %%
data = df.copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
brand = []
for i in range(len(data)):
    brand.append(data['name'][i].split()[0])
data['brand'] = brand

# %%
data.head()
# Out:
#                                             img_link  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...
# 1  https://rukminim1.flixcart.com/image/312/312/x...
# 2  https://rukminim1.flixcart.com/image/312/312/l...
# 3  https://rukminim1.flixcart.com/image/312/312/x...
# 4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price  \
# 0             Lenovo Intel Core i5 11th Gen  62990
# 1            Lenovo V15 G2 Core i3 11th Gen  37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen  49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen  33990
# 4                   Lenovo Athlon Dual Core  18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 2  Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 3  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
# 4      AMD Athlon Dual Core Processor   4 GB DDR4 RAM
#
#                                    os              storage  display  rating  \
# 0         Windows 11 Operating System           512 GB SSD     15.6     4.5
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD     15.6     4.4
# 2         Windows 11 Operating System           512 GB SSD     15.6     4.4
# 3  64 bit Windows 11 Operating System           512 GB SSD     15.6     4.3
# 4                DOS Operating System           256 GB SSD     14.0     3.8
#
#    no_of_ratings  no_of_reviews   brand
# 0           14.0            1.0  Lenovo
# 1           53.0            3.0  Lenovo
# 2         4733.0          463.0    ASUS
# 3        10406.0         1040.0    ASUS
# 4           18.0            3.0  Lenovo

# %%
plt.figure(figsize=(15,6))
sns.histplot(data, x = 'brand')
plt.title('Laptop brands')
plt.xticks(rotation=40, horizontalalignment='right', 
           fontsize=10)
plt.show()

# %%
data.groupby('brand').size().sort_values(ascending=False).head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='brand'>

# %% [markdown]
# We have ASUS, Lenovo, DELL, HP and acer as top 5 brands

# %%
data.query('price == price.max()')
# Out:
#                                               img_link  \
# 966  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                     name   price  \
# 966  MSI Raider GE67 HX Core i9 12th Gen  419990
#
#                               processor             ram  \
# 966  Intel Core i9 Processor (12th Gen)  32 GB DDR5 RAM
#
#                                      os   storage  display  rating  \
# 966  64 bit Windows 11 Operating System  2 TB SSD     15.6     0.0
#
#      no_of_ratings  no_of_reviews brand
# 966            0.0            0.0   MSI

# %%
data.query('price == price.min()')
# Out:
#                                              img_link  \
# 74  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                             name  price  \
# 74  ASUS Chromebook Flip Touch Celeron Dual Core  15990
#
#                             processor              ram  \
# 74  Intel Celeron Dual Core Processor  4 GB LPDDR4 RAM
#
#                          os   storage  display  rating  no_of_ratings  \
# 74  Chrome Operating System  2 TB SSD     11.6     4.0         1853.0
#
#     no_of_reviews brand
# 74          287.0  ASUS

# %%
plt.figure(figsize=(12,6))
sns.histplot(data, x = 'price',bins=40)
plt.title('Price Range of the Laptops')
plt.show()

# %% [markdown]
# From the plot,
#
# We have laptops ranging over the price of Rs.15990-Rs.419990
#
# We can observe that most of the laptops lie in the price range of Rs.40000-Rs.70000

# %%
plt.figure(figsize=(12,6))
plt.scatter(data.processor, data['price'])
plt.xticks(rotation=60, horizontalalignment='right', 
           fontsize=7);

# %% [markdown]
# Intel Core i9 Processor(12th Gen) has the greatest price of Rs.419990
#
# We can't come in to any conclusion based on the processor and the price. They are not much related.
#
# Let's examine the frequency

# %%
plt.figure(figsize=(12, 6))
data.groupby('processor').size().sort_values(ascending=False).head(7).plot(kind='bar');

# %% [markdown]
# We examined that most of the laptops range over the price 40000-70000.
#
# Therefore there is high chance that these laptops have the processor among those mentioned above.

# %%
plt.figure(figsize=(15, 6))
plt.scatter(data['ram'],data['price'])
plt.xticks(rotation=60, horizontalalignment='right', 
           fontsize=7);

# %% [markdown]
# We can't exactly find any relation between RAM and the price.
#
# But we can find there is only single laptop with a certain price for particular RAM.
#
# 16 GB DDR3 RAM, 32 GB LPDDR4X RAM, 16 GB LPDDR4 RAM, 32 GB Unified Memory RAM these are of particular prices and may be with a single piece laptop.
#
# Let's get into the frequency

# %%
ram_gb = []
for i in range(len(data)):
    ram_gb.append(data['ram'][i].split()[0])
data['ram_gb'] = ram_gb

# %%
data.head(1)
# Out:
#                                             img_link  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...
#
#                             name  price                           processor  \
# 0  Lenovo Intel Core i5 11th Gen  62990  Intel Core i5 Processor (11th Gen)
#
#               ram                           os     storage  display  rating  \
# 0  16 GB DDR4 RAM  Windows 11 Operating System  512 GB SSD     15.6     4.5
#
#    no_of_ratings  no_of_reviews   brand ram_gb
# 0           14.0            1.0  Lenovo     16

# %%
data.groupby('ram_gb').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='ram_gb'>

# %% [markdown]
# We have laptops with ram ranging from 4 to 32 GB.
#
# Most of the laptops are of 8 GB and 16 GB RAM.
#
# As we examined that most of the laptops range over the price 40000-70000, there is high chance that these laptops have the ram as 8 and 16 GB.

# %%
data.groupby('os').size().sort_values(ascending=False).plot(kind='bar');
plt.xlabel("Operating System")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# From this analysis, we can find the most probable Operating system we choose is 64 bit Windows 11 Operating System

# %%
data.head(1)
# Out:
#                                             img_link  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...
#
#                             name  price                           processor  \
# 0  Lenovo Intel Core i5 11th Gen  62990  Intel Core i5 Processor (11th Gen)
#
#               ram                           os     storage  display  rating  \
# 0  16 GB DDR4 RAM  Windows 11 Operating System  512 GB SSD     15.6     4.5
#
#    no_of_ratings  no_of_reviews   brand ram_gb
# 0           14.0            1.0  Lenovo     16

# %%
plt.figure(figsize=(15, 6))
plt.bar(data['storage'],data['price'])
plt.xticks(rotation=60, horizontalalignment='right', 
           fontsize=7);

# %% [markdown]
# We can observe that, higher the storage, higher the price.

# %%
data.groupby('storage').size().sort_values(ascending=False).head(5).plot(kind='bar');
plt.xlabel("Storage")
plt.ylabel("Frequency")
plt.xticks(rotation=60, horizontalalignment='right', 
           fontsize=7);

# %% [markdown]
# We can see 512 GB SSD is more frequent when compared to even more storage laptops.
#
# People may not use very high storage like 1,2,4 TB SSD laptops which are are costlier until they require higher specifications and storage, so they prefer the laptops which can be of enough storage to them.
#
# Also, many of them don't prefer less stoarge laptops even though they are cheaper, because they can't come upto their expectations. They can be of very limited storage and may get get into the situation of out of storage.
#
# Hence we can say that 512 GB SSD(considering size and price) are more frequent due to this reason

# %%
data.groupby('display').size().sort_values(ascending=False).head(5).plot(kind='bar');
plt.xlabel("Display size(in inches)")
plt.ylabel("Frequency")
plt.xticks(rotation=60, horizontalalignment='right', 
           fontsize=7);

# %% [markdown]
# We can see 15.6 Inch display is more frequent because it is more comfortable to use.
#
# People may need to work with 2 or more tabs at a time and it may not be comfortable with lesser display size to view them clearly.
#
# Also, greater than 16 inch size are less frequent. This may be due to the reason that it is hard to carry all the time easily from one place to another.
#
# Hence considering these situations 15.6 inch display are more frequent.

# %%
sns.pairplot(data);

# %%
data.head(1)
# Out:
#                                             img_link  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...
#
#                             name  price                           processor  \
# 0  Lenovo Intel Core i5 11th Gen  62990  Intel Core i5 Processor (11th Gen)
#
#               ram                           os     storage  display  rating  \
# 0  16 GB DDR4 RAM  Windows 11 Operating System  512 GB SSD     15.6     4.5
#
#    no_of_ratings  no_of_reviews   brand ram_gb
# 0           14.0            1.0  Lenovo     16

# %%
data['ram_gb'] = data['ram_gb'].astype(int)
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print(num_cols)
# Out:
# ['price', 'display', 'rating', 'no_of_ratings', 'no_of_reviews', 'ram_gb']

# %%
# plt.figure(figsize=(25, 10))
sns.heatmap(
    data[num_cols].corr(), annot=True, vmin=-1, vmax=1, fmt=".1f", cmap="Spectral")
plt.show()

# %%
new_df = data[data['no_of_ratings'] != 0]
plt.scatter(new_df['price'],new_df['no_of_ratings'])
plt.xlabel('Price in INR')
plt.ylabel("Number of Ratings")
plt.title("Price VS Number of Ratings")
plt.show()

# %% [markdown]
# When the price is between 25,000 to 1,00,000 there are more number of rating which means that this is the price range in which most people are interested upon

# %% [markdown]
# ### Mostly Rated

# %%
laptops_sorted_by_rating = data.sort_values(['no_of_ratings'], ascending=False)

plt.figure(figsize=(10,4))
plt.bar(laptops_sorted_by_rating['name'][:20], laptops_sorted_by_rating['no_of_ratings'][:20])
plt.xticks(rotation=40, horizontalalignment='right', 
           fontsize=10)

print()

# %% [markdown]
# ### Ratings

# %%
new_df = data[data['rating'] != 0]
plt.scatter(new_df['price'],new_df['rating'])
plt.xlabel('Price in INR')
plt.ylabel("Rating")
plt.title("Price VS Ratings")
plt.show()

# %%
data[data.rating == 5.0]
# Out:
#                                               img_link  \
# 11   https://rukminim1.flixcart.com/image/312/312/x...
# 60   https://rukminim1.flixcart.com/image/312/312/x...
# 96   https://rukminim1.flixcart.com/image/312/312/k...
# 111  https://rukminim1.flixcart.com/image/312/312/x...
# 201  https://rukminim1.flixcart.com/image/312/312/l...
# 209  https://rukminim1.flixcart.com/image/312/312/l...
# 262  https://rukminim1.flixcart.com/image/312/312/l...
# 282  https://rukminim1.flixcart.com/image/312/312/k...
# 302  https://rukminim1.flixcart.com/image/312/312/l...
# 399  https://rukminim1.flixcart.com/image/312/312/l...
# 400  https://rukminim1.flixcart.com/image/312/312/l...
# 528  https://rukminim1.flixcart.com/image/312/312/k...
# 574  https://rukminim1.flixcart.com/image/312/312/k...
# 609  https://rukminim1.flixcart.com/image/312/312/k...
# 620  https://rukminim1.flixcart.com/image/312/312/x...
# 666  https://rukminim1.flixcart.com/image/312/312/l...
# 701  https://rukminim1.flixcart.com/image/312/312/j...
# 713  https://rukminim1.flixcart.com/image/312/312/k...
# 948  https://rukminim1.flixcart.com/image/312/312/k...
#
#                                                   name   price  \
# 11            ASUS Vivobook 14 (2022) Core i5 12th Gen   66990
# 60            ASUS Vivobook 14 (2022) Core i3 12th Gen   46990
# 96                            HP OMEN Core i7 11th Gen   88499
# 111                HP Pavilion Ryzen 5 Hexa Core 5625U   61990
# 201                      DELL Ryzen 7 Octa Core AMD R7   99990
# 209                      DELL Ryzen 7 Octa Core AMD R7   88490
# 262     ASUS ROG Strix SCAR 15 (2022) Core i9 12th Gen  281990
# 282  ASUS ROG Strix G15 with 90Whr Battery Ryzen 7 ...  146990
# 302                          APPLE 2022 MacBook AIR M2  139990
# 399          acer Predator Helios 300 Core i9 11th Gen  139999
# 400          acer Predator Helios 300 Core i7 12th Gen  156490
# 528                            Lenovo Core i3 10th Gen   37890
# 574              acer Aspire 5 Ryzen 7 Octa Core 5700U   59990
# 609                ASUS ExpertBook B9 Core i7 10th Gen  154990
# 620  ASUS ZenBook Duo 14 (2021) Touch Panel Core i5...   79990
# 666         ASUS ROG Flow X13 Ryzen 7 Octa Core 6800HS  114990
# 701                ASUS ZenBook Pro 15 Core i9 8th Gen  209690
# 713                            Lenovo Core i3 10th Gen   37890
# 948                          HP Intel Core i5 10th Gen  127000
#
#                               processor                      ram  \
# 11   Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
# 60   Intel Core i3 Processor (12th Gen)            8 GB DDR4 RAM
# 96   Intel Core i7 Processor (11th Gen)           16 GB DDR4 RAM
# 111     AMD Ryzen 5 Hexa Core Processor           16 GB DDR4 RAM
# 201     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 209     AMD Ryzen 7 Octa Core Processor           16 GB DDR4 RAM
# 262  Intel Core i9 Processor (12th Gen)           32 GB DDR5 RAM
# 282     AMD Ryzen 7 Octa Core Processor           16 GB DDR4 RAM
# 302                  Apple M2 Processor  8 GB Unified Memory RAM
# 399  Intel Core i9 Processor (11th Gen)           16 GB DDR4 RAM
# 400  Intel Core i7 Processor (12th Gen)           16 GB DDR5 RAM
# 528  Intel Core i3 Processor (10th Gen)            8 GB DDR4 RAM
# 574     AMD Ryzen 7 Octa Core Processor            8 GB DDR4 RAM
# 609  Intel Core i7 Processor (10th Gen)         16 GB LPDDR3 RAM
# 620  Intel Core i5 Processor (11th Gen)        16 GB LPDDR4X RAM
# 666     AMD Ryzen 7 Octa Core Processor         16 GB LPDDR5 RAM
# 701   Intel Core i9 Processor (8th Gen)           16 GB DDR4 RAM
# 713  Intel Core i3 Processor (10th Gen)            4 GB DDR4 RAM
# 948  Intel Core i5 Processor (10th Gen)            8 GB DDR4 RAM
#
#                                      os     storage  display  rating  \
# 11   64 bit Windows 11 Operating System  512 GB SSD     14.0     5.0
# 60   64 bit Windows 11 Operating System  512 GB SSD     14.0     5.0
# 96   64 bit Windows 11 Operating System    1 TB SSD     16.1     5.0
# 111  64 bit Windows 11 Operating System  512 GB SSD     14.0     5.0
# 201  64 bit Windows 11 Operating System  512 GB SSD     15.6     5.0
# 209  64 bit Windows 11 Operating System  512 GB SSD     15.6     5.0
# 262  64 bit Windows 11 Operating System    1 TB SSD     15.6     5.0
# 282  64 bit Windows 11 Operating System    1 TB SSD     15.6     5.0
# 302             Mac OS Operating System  512 GB SSD     13.6     5.0
# 399  64 bit Windows 11 Operating System    1 TB SSD     15.6     5.0
# 400  64 bit Windows 11 Operating System    1 TB SSD     15.6     5.0
# 528         Windows 10 Operating System  256 GB SSD     14.0     5.0
# 574  64 bit Windows 10 Operating System  512 GB SSD     15.6     5.0
# 609  64 bit Windows 10 Operating System    1 TB SSD     14.0     5.0
# 620  64 bit Windows 11 Operating System  512 GB SSD     14.0     5.0
# 666  64 bit Windows 11 Operating System    1 TB SSD     13.4     5.0
# 701  64 bit Windows 10 Operating System    1 TB SSD     15.6     5.0
# 713         Windows 10 Operating System  256 GB SSD     15.6     5.0
# 948  64 bit Windows 10 Operating System  512 GB SSD     13.3     5.0
#
#      no_of_ratings  no_of_reviews   brand  ram_gb
# 11             4.0            0.0    ASUS      16
# 60             7.0            2.0    ASUS       8
# 96             3.0            1.0      HP      16
# 111            3.0            1.0      HP      16
# 201            3.0            0.0    DELL      16
# 209            7.0            1.0    DELL      16
# 262            4.0            0.0    ASUS      32
# 282            6.0            0.0    ASUS      16
# 302            8.0            2.0   APPLE       8
# 399            7.0            1.0    acer      16
# 400            4.0            0.0    acer      16
# 528            4.0            0.0  Lenovo       8
# 574            3.0            0.0    acer       8
# 609            3.0            0.0    ASUS      16
# 620            3.0            0.0    ASUS      16
# 666            3.0            0.0    ASUS      16
# 701            4.0            0.0    ASUS      16
# 713            1.0            1.0  Lenovo       4
# 948            2.0            1.0      HP       8

# %% [markdown]
# # Model

# %%
df1 = df.drop(['img_link', 'name'], axis=1)
categorical_features =df1.columns[(df1.dtypes == 'object') == True].to_list()
categorical_features
# Out:
# ['processor', 'ram', 'os', 'storage']

# %%
for feature in categorical_features:
    uniq = df1[feature].unique()
    
    new_feature = []
    for el in df1[feature]:
        new_feature.append(len(uniq) - np.where(uniq==el)[0][0])
    
    df1[feature] = new_feature
    
df1.head()
# Out:
#    price  processor  ram  os  storage  display  rating  no_of_ratings  \
# 0  62990         59   22  11       16     15.6     4.5           14.0
# 1  37500         58   21  10       15     15.6     4.4           53.0
# 2  49990         57   21  11       16     15.6     4.4         4733.0
# 3  33990         56   21  10       16     15.6     4.3        10406.0
# 4  18990         55   20   9       14     14.0     3.8           18.0
#
#    no_of_reviews
# 0            1.0
# 1            3.0
# 2          463.0
# 3         1040.0
# 4            3.0

# %%
X = df1.drop(['price'], axis=1)
Y = df1['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=200)

model.fit(x_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
yhat = model.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score

# %%
print('r2 score: ', r2_score(y_test, yhat))

plt.scatter(np.linspace(0, len(yhat), len(yhat)), yhat, alpha=0.5, label='predictions')
plt.scatter(np.linspace(0, len(y_test), len(y_test)), y_test, alpha=0.5, label='true')
plt.legend()
# Out:
# r2 score:  0.8374767534611932
